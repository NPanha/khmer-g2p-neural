# %%
import sys, os
sys.path.insert(0, os.path.abspath("src"))

# %%
from khmer_g2p.pipeline import KhmerG2P

pipe = KhmerG2P.from_paths("checkpoints_v04/best.pt", "data/lexicon.tsv")
pipe
# Out:
# c:\Users\User\miniconda3\envs\ai\Lib\site-packages\torch\nn\modules\transformer.py:382: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.norm_first was True
#   warnings.warn(
# KhmerG2PPipeline(lexicon_size=69168, segmenter_vocab=69168, beam=4, word_boundary='|', hit_rate=0.000)

# %%
text = "រន្ធទាំងនេះអាចមានជម្រៅដល់ទៅ ម្ភៃម៉ែត្រ ឬច្រើនជាងនេះ ប៉ុន្តែការងារនេះពិតជាគ្រោះថ្នាក់ណាស់ ដោយសារតែមានហានិភ័យនៃការបាក់ដី"

# %%
pipe.khm_phonemize(text)
# Out:
# 'run teaŋnih ʔaacɑm ʔaa nɔɔ cumrɨw ɗɑl tɨw mphej maet rɨɨ craən cieŋ nih pontae kaaŋie nih pɨtcie kruəhtnak nah ɗaojsaatae mien haaniʔphej nej kaa ɓak ɗəj'
